# %%
! pip install google-cloud-storage google-auth
# Out:
# Requirement already satisfied: google-cloud-storage in c:\users\kopal\anaconda3\envs\microns\lib\site-packages (3.7.0)
# Requirement already satisfied: google-auth in c:\users\kopal\anaconda3\envs\microns\lib\site-packages (2.47.0)
# Requirement already satisfied: google-api-core<3.0.0,>=2.27.0 in c:\users\kopal\anaconda3\envs\microns\lib\site-packages (from google-cloud-storage) (2.29.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in c:\users\kopal\anaconda3\envs\microns\lib\site-packages (from google-cloud-storage) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in c:\users\kopal\anaconda3\envs\microns\lib\site-packages (from google-cloud-storage) (2.8.0)
# Requirement already satisfied: requests<3.0.0,>=2.22.0 in c:\users\kopal\anaconda3\envs\microns\lib\site-packages (from google-cloud-storage) (2.32.5)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in c:\users\kopal\anaconda3\envs\microns\lib\site-packages (from google-cloud-storage) (1.8.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\kopal\anaconda3\envs\microns\lib\site-packages (from google-auth) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\kopal\anaconda3\envs\microns\lib\site-packages (from google-auth) (4.9.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\kopal\anaconda3\envs\microns\lib\site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\kopal\anaconda3\envs\microns\lib\site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (6.33.3)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\kopal\anaconda3\envs\microns\lib\site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (1.27.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kopal\anaconda3\envs\microns\lib\site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kopal\anaconda3\envs\microns\lib\site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kopal\anaconda3\envs\microns\lib\site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kopal\anaconda3\envs\microns\lib\site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (2025.11.12)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\kopal\anaconda3\envs\microns\lib\site-packages (from rsa<5,>=3.1.4->google-auth) (0.6.1)

# %%
import google.auth
from google.auth.transport.requests import Request
from google.cloud import storage

# %%
BUCKET_NAME = 'dk_jhu_test_bucket'
LOCAL_FILE_PATH = 'test_file.txt'
DEST_OBJ_NAME = 'test_file.txt'

PROJECT = 'dk-jhu-spine-detect-01'

# %%
credentials, _ = google.auth.default(
    scopes=["https://www.googleapis.com/auth/devstorage.read_write"],
)
credentials

# %%
# credentials.refresh(Request())
# access_token = credentials.token

# %%
client = storage.Client()

bucket = client.bucket(BUCKET_NAME)
blob = bucket.blob(DEST_OBJ_NAME)
blob.upload_from_file(LOCAL_FILE_PATH)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 client = storage.Client()
#       3 bucket = client.bucket(BUCKET_NAME)
#       4 blob = bucket.blob(DEST_OBJ_NAME)
#
# File c:\Users\kopal\anaconda3\envs\microns\Lib\site-packages\google\cloud\storage\client.py:265, in Client.__init__(self, project, credentials, _http, client_info, client_options, use_auth_w_custom_endpoint, extra_headers, api_key)
#     262             no_project = True
#     263             project = "<none>"
# --> 265 super(Client, self).__init__(
#     266     project=project,
#     267     credentials=credentials,
#     268     client_options=client_options,
#     269     _http=_http,
#     270 )
#     272 # Validate that the universe domain of the credentials matches the
#     273 # universe domain of the client.
#     274 if self._credentials.universe_domain != self.universe_domain:
#
# File c:\Users\kopal\anaconda3\envs\microns\Lib\site-packages\google\cloud\client\__init__.py:339, in ClientWithProject.__init__(self, project, credentials, client_options, _http)
#     338 def __init__(self, project=None, credentials=None, client_options=None, _http=None):
# --> 339     _ClientProjectMixin.__init__(self, project=project, credentials=credentials)
#     340     Client.__init__(
#     341         self, credentials=credentials, client_options=client_options, _http=_http
#     342     )
#
# File c:\Users\kopal\anaconda3\envs\microns\Lib\site-packages\google\cloud\client\__init__.py:290, in _ClientProjectMixin.__init__(self, project, credentials)
#     287     project = self._determine_default(project)
#     289 if project is None:
# --> 290     raise EnvironmentError(
#     291         "Project was not passed and could not be "
#     292         "determined from the environment."
#     293     )
#     295 if isinstance(project, bytes):
#     296     project = project.decode("utf-8")
#
# OSError: Project was not passed and could not be determined from the environment.
